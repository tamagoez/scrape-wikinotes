# %% [markdown]
# <a href="https://colab.research.google.com/github/tamagoez/scrape-wikinotes/blob/main/Web_Scrape_log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

raw = requests.get('https://raw.githubusercontent.com/tamagoez/vividarmy-wikinotes/main/system/event/opus.mdx')
rawsoup = BeautifulSoup(raw.text, 'html.parser')
rawsoupcut = rawsoup.text.split('tags: [')[1].split(']')[0]
trimraw = rawsoupcut.split(', ')
print(trimraw)

for item in trimraw:
  geturl = 'https://www.google.com/search?q=vividarmy+' + item + '&ie=UTF-8&num=300'
  response = requests.get(geturl)
  soup = BeautifulSoup(response.text, 'html.parser')
  h3 = soup.find_all('div', class_='BNeawe vvjwJb AP7Wnd')
  num = 0
  for n in h3:
    # scrape = item[0].split('>')[1].split('</title')[0]
    title = n.text
    # print(title)
    # https://note.nkmk.me/python-str-search/
    # print('WikiNotes' in title)
    if 'WikiNotes' in title:
        print(num)
    else:
        num += 1
# Out:
# ['event', 'opus']

# %%
import requests
from bs4 import BeautifulSoup


xmlraw = requests.get('https://vividarmy-wikinotes.vercel.app/sitemap.xml')
# print(xmlraw.text)
xmlsoup = BeautifulSoup(xmlraw.text, "xml")
# print(xmlsoup)
findsoup = xmlsoup.find_all('loc')
for item in findsoup:
  print(item.text)
# Out:
# https://vividarmy-wikinotes.vercel.app/blog
# https://vividarmy-wikinotes.vercel.app/blog/archive
# https://vividarmy-wikinotes.vercel.app/blog/how-to-call-wikinotes
# https://vividarmy-wikinotes.vercel.app/blog/summon
# https://vividarmy-wikinotes.vercel.app/blog/tags
# https://vividarmy-wikinotes.vercel.app/blog/tags/update
# https://vividarmy-wikinotes.vercel.app/blog/tags/wikinotes
# https://vividarmy-wikinotes.vercel.app/help/tags
# https://vividarmy-wikinotes.vercel.app/help/tags/status
# https://vividarmy-wikinotes.vercel.app/q-and-a
# https://vividarmy-wikinotes.vercel.app/q-and-a/archive
# https://vividarmy-wikinotes.vercel.app/q-and-a/difference-vivivdarmy-topwar
# https://vividarmy-wikinotes.vercel.app/q-and-a/tags
# https://vividarmy-wikinotes.vercel.app/q-and-a/tags/system
# https://vividarmy-wikinotes.vercel.app/q-and-a/tags/topwar
# https://vividarmy-wikinotes.vercel.app/q-and-a/tags/vividarmy
# https://vividarmy-wikinotes.vercel.app/q-and-a/tags/wiki
# ...

# %%
import requests
from bs4 import BeautifulSoup
import time


xmlraw = requests.get('https://vividarmy-wikinotes.vercel.app/sitemap.xml')
# print(xmlraw.text)
xmlsoup = BeautifulSoup(xmlraw.text, "xml")
# print(xmlsoup)
findsoup = xmlsoup.find_all('loc')
for item in findsoup:
  print(item.text)
  response = requests.get('https://www.google.com/search?q=' + item.text + '&ie=UTF-8&num=100')
  soup = BeautifulSoup(response.text, 'html.parser')
  h3 = soup.find_all('div')
  num = 0
  crawl = 'false'
  for item in h3:
    # scrape = item[0].split('>')[1].split('</title')[0]
    title = item.text
    print(title)
    # https://note.nkmk.me/python-str-search/
    # print('WikiNotes' in title)
    time.sleep(0.5)
    if 'WikiNotes' in title:
        print(num)
    else:
        num += 1
        print('Failed')
# Out:
# https://vividarmy-wikinotes.vercel.app/blog
#
#
#
#
#
#   In order to continue, please enable javascript on your web browser.
#
#
#
# var submitCallback = function(response) {document.getElementById('captcha-form').submit();};
#
#
#
#
#
# About this page
#
# Our systems have detected unusual traffic from your computer network.  This page checks to see if it's really you sending the requests, and not a robot.  Why did this happen?
#
# ...
